# %% [markdown]
# # Tecniques:
#     ### 1. Use shallow NN because there will be less number of gradients and less number of multiplication because if we have large NN then for there will be too much gradient value less than 1 and multiplcation of all these gradient make the value of gradient is very less.
#
#     ### 2. Using Relu activation function
#
#     ### 3. Proper weigth initialization
#
#     ### 4. Batch Normalization is a Layer.
#
#     ### 5.Residual NN.
