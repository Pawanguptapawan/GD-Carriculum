# %%
# problems with Convolution:
    # 1. Memory issues -> if we process entire image without decresing the height and width this can be issue of memory oversize.
    # 2. Translation variance: means in Comvolution every feeature in image is dependent on the location. but we don't want so basically we apply the pooling (generally maxPooling) to make these feature location independent (translation invariance). so at the time of features extraction it won't be a problem.



# Advantage of Pooling:
    # reduces the size of image. 
    # Translation invariance. 
    # enhanced features( in maxpooling only)
    #  No need of training.
