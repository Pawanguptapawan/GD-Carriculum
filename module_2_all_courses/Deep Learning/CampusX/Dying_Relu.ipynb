# %%
# Dying Relu:
    # dead neuron : if the weights associated with a neuron not changes at the time of weights updation means for every input the output is 0 then this is called dead neuron.  max(z,0)=0   . once a neuron is dead then it will be forever dead. 
    # if more 50% Neuron is dead in NN then NN cannot capture the patterns very well mean it cannot caputre high level patterns because more then 50% neurons are dead. 

    # a1 = max(z,0)
    # if z<0 then a1=0  then da1/dW =0
    # W = W - da1/dW  => W = W

    # Reasons:
        # if LR is very high (W becomes negative by updation)
        # High -ve Bias (b).
    
    # Solution:
        # Set lower LR.
        # bias -> +ve value 
        # Don;t use relu -> use variants (Leaky relu , parametric relu , Elue , Selu )
