# %%
# Fine tunning NN hyperparameters like (hidden_layer,neurons_per layer , LR , optimizer , Batch size , activation function , epochs)

# By solving problems:
    # Vanishing / Exploiding gradient (weight init, activation function , Batch Norm , Gradient Clipping)
    # Not enough data(transfer learninng , unsupervised pretraining )
    # Slow training  (optimizers , learning rate scheduler)
    # Overfitting  (l1 or l2 regullrizer, early stopping , Dropout)


# Batch size  hyperparameter:
    # smaller batch size : training slow , more generalized results
    # large batch size : training faster , less generalize result  but we can optimize it by introducing the learing rate scheduler. like in beginnnig epochs learning rate is less but by the time for higher epochs increase the learning rate this is called warming up the LR.

# Number of Epochs : we can use Early stopping to reduce the overfitting.
