# %%
import torch
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
torch.tensor([1,2,3],dtype=float)
# Out:
# tensor([1., 2., 3.], dtype=torch.float64)

# %%
x=torch.tensor([3],dtype=torch.float32,requires_grad=True)
y=x**2

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([6.])

# %%
import torch.nn as nn
class Model(nn.Module):
    def __init__(self,num_features):
        super().__init__()
        self.network=nn.Sequential(
            nn.Linear(num_features,3),
            nn.ReLU(),
            nn.Linear(3,1),
            nn.Sigmoid()
        )
        

    def forward(self,features):
        out=self.network(features)
        return out

# %%
features=torch.rand(10,5)
model=Model(5)

# %%
y_true = torch.randint(0,2,(10,1)).float()
y_pred=model(features)
y_pred.shape
# Out:
# torch.Size([10, 1])

# %%
eps = 1e-7

loss = -(y_true * torch.log(y_pred + eps) +
         (1 - y_true) * torch.log(1 - y_pred + eps))
loss
# Out:
# tensor([[0.5867],
#         [0.6026],
#         [0.7945],
#         [0.8199],
#         [0.7735],
#         [0.5821],
#         [0.6258],
#         [0.5827],
#         [0.6064],
#         [0.6200]], grad_fn=<NegBackward0>)

# %%
model.linear1.bias
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 model.linear1.bias
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torch/nn/modules/module.py:1965, in Module.__getattr__(self, name)
#    1963     if name in modules:
#    1964         return modules[name]
# -> 1965 raise AttributeError(
#    1966     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1967 )
#
# AttributeError: 'Model' object has no attribute 'linear1'

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.8.0)

# %%
from torchinfo import summary
summary(model,input_size=(10,5))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model                                    [10, 1]                   --
# ├─Sequential: 1-1                        [10, 1]                   --
# │    └─Linear: 2-1                       [10, 3]                   18
# │    └─ReLU: 2-2                         [10, 3]                   --
# │    └─Linear: 2-3                       [10, 1]                   4
# │    └─Sigmoid: 2-4                      [10, 1]                   --
# ==========================================================================================
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================

# %%
nn.Loss
