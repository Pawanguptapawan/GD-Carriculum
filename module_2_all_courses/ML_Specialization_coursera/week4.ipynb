# %%
import tensorflow as tf

# %%
# Decision Tree
# when to stop spilling
# when a node is 100% one class
# when splitting a node will result in the tree exceeding a maximum depth
# when improvements in purity score are below a threshold.
# when number of examples in a node is below a threshold
# no. of leafs per node greater then threshold.


# measuring purity
# P1 prob of one class
# P0 = 1-P1

# H(P1) = -P1*log(P1) - P0*log(P0)
# entropy : a metric from information theory used to measure impurity, disorder, or uncertainty within a set of data
# Values:
# 0 (Zero Entropy): Perfect purity (all data points belong to one class).
# 1 (High Entropy): Maximum impurity (classes are evenly mixed).

# Formula: 
# , where 
#  is the probability of class 
# High Entropy/Gini: Node is mixed.
# Low Entropy/Gini: Node is pure. 


# info gain:    sum(fraction of distribution of a feature * H(pi))
# Gain(S,A)=Entropy(S)−∑∣S∣/Sv.Entropy(S)

 
#  The formula of Entropy is given by:

# H = -(\sum p_i \log_2{p_i})
# IG_{split} = H - (\sum \frac{|D_j|}{|D|} * H_{j})



# The formula of Intrinsic Information is:

# II = - (\sum \frac{|D_j|}{|D|} * \log_2\frac{|D_j|}{|D|})

# Gain Ratio = \frac{\text{Information Gain}}{\text{Intrinsic Information}}

# start with all examples at the root node
# calculate info gain for all possible features and pich the one with highest info gain
# split dataset according to selected fearures and create left and right branchees of the tree
# keep repeating splitting process until stopping criteria is met.


#  regresion with decision trees:

# %%
# Ensembles: One of the weaknesses of using a single decision tree is that that decision tree can be highly sensitive to small changes in the data.It is not robust.
# We use ensembles of trees instead of single tree. this is calld random forest collection of multiple decision tree.
# Sampling with  replacement : 


# randomizing the feature choice: at each node,when chooosing a feature to use to split if n features a re avaialbele pick a random subset of k<n features and allow the algo to only choose from that subset of features.
# algo is robust if k=sqrt(n)

# %%
# XGBoost(Xtreme gradient boosting)   decision tree : it runs quickly. 
# for b=1 to B:
# use sampling with replacement to create a new training set of size m but instead of picking from all examples with equal probability , make it more likely to  pick misclassified examples from previously trained trees.
# it is good choice of default splitting criteria and criteria for when to stop splitting.
# built in regularization to prevent overfitting.
# from xgboost from XGBClassifier 

# for regression:
# from xgboost import XGBRegressor

# when to use decision trees v/s neural network:
# decision tree and tree ensembles works well on tabular data.
# DT not recoomended for unstructred data 
# DT is fast to train
# small decision trees may be human interpretable.
# fro neural net works well on all type of data.
# may be slower than a decision tree
# works with transfer learning
# when building a system of multiple models working together , it might be easier to string together multipleneural networks.
