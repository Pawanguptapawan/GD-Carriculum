# %%
# Reinforcement learning  from human feedback(RLHF)   align llms to the human prefrences.

# %%
# Align model with human feedbacks
# Steps for fine tune the model with RLHF
# prepare the dataset and model complete the prompts.
# collect the feedback from human based on the completions.
# prepare labeled data for training: convert rankings into pairwise training data for the reward model.
# train model to predict preferred completion from {yj,yk} for x prompt
# use the reward model as a binary classifier to provide reward value for each prompt completion pair.

# %%
# Fine tune model with RL
# prompt dataset -> instruct LLM ->reward model -> RL algorithm -> update weights ->RL updated LLM ->prompt dataset -> .....


# RL algo take reward model output and train the model.
# PPO RL algo -> proximal policy algorithm.

# %%
# PPO with instruct LLM goes over 2 phases
# 1. create completions. (the xepexted reward of the completion is important quantitiy we estimate this quantity with a separate head of the LLM called tha value function. we try to minimze the differnece between estimated future reward and known future award. we wnant to minimize the loss function.
# 2. Model update: the policy loss is the main objective that the ppo algo trtying to optimize during training.  objective function =  caculate policy loss -> calculate value loss ->  calculate entropy loss

# %%
 # reward hacking :  prompt dataset -> instruct (completion) -> toxisity reward model -> ppo -> RL updated LLM->toxi.........
# occurs when a reinforcement learning agent finds a loophole in its reward function to maximize scores without actually achieving the intended goal.

# avoidance ->  KL divergence shift panelty
