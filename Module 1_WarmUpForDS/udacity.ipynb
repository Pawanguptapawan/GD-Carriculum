# %%
#!/usr/bin/python3

""" 
    This is the code to accompany the Lesson 2 (SVM) mini-project.

    Use a SVM to identify emails from the Enron corpus by their authors:    
    Sara has label 0
    Chris has label 1
"""
    
import sys
from time import time
from email_preprocess import preprocess


### features_train and features_test are the features for the training
### and testing datasets, respectively
### labels_train and labels_test are the corresponding item labels
features_train, features_test, labels_train, labels_test = preprocess()


#########################################################
### your code goes here ###
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
clf = SVC(kernel="linear")

# 2. Train the model
t0 = time()
clf.fit(features_train, labels_train)
print(f"Training time: {round(time()-t0, 3)}s")

# 3. Make predictions
t1 = time()
predict = clf.predict(features_test) # Fixed the typo here
print(f"Prediction time: {round(time()-t1, 3)}s")

# 4. Calculate accuracy
accuracy = accuracy_score(labels_test, predict)
print(f"Accuracy: {accuracy}")
#########################################################

#########################################################
'''
You'll be Provided similar code in the Quiz
But the Code provided in Quiz has an Indexing issue
The Code Below solves that issue, So use this one
'''

# features_train = features_train[:int(len(features_train)/100)]
# labels_train = labels_train[:int(len(labels_train)/100)]

#########################################################




# 1. Initialize the classifier 
# Using kernel="linear" is a common first step for text classification
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 13
#      11 import sys
#      12 from time import time
# ---> 13 from email_preprocess import preprocess
#      16 ### features_train and features_test are the features for the training
#      17 ### and testing datasets, respectively
#      18 ### labels_train and labels_test are the corresponding item labels
#      19 features_train, features_test, labels_train, labels_test = preprocess()
#
# ModuleNotFoundError: No module named 'email_preprocess'
