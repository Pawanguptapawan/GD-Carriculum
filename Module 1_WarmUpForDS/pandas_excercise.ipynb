# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./chipotle.tsv',sep='\t')

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='str')

# %%
c=df.groupby('item_name').sum()
c=c.sort_values(['quantity'],ascending=False)
c.head(1)
df.info()
df['item_price'] = df['item_price'].str.replace('$', '', regex=False).astype(float)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   str
#  3   choice_description  3376 non-null   str
#  4   item_price          4622 non-null   str
# dtypes: int64(2), str(3)
# memory usage: 180.7 KB

# %%
df['item_price'].head()
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: item_price, dtype: float64

# %%
df.groupby('item_name').sum().sort_values(['quantity'],ascending=False).head(1)
# Out:
#               order_id  quantity  \
# item_name
# Chicken Bowl    713926       761
#
#                                              choice_description  item_price
# item_name
# Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     7342.73

# %%
df.groupby('choice_description').sum().sort_values(['quantity'],ascending=False).head(1)
# Out:
#                     order_id  quantity  \
# choice_description
# [Diet Coke]           123455       159
#
#                                                             item_name  \
# choice_description
# [Diet Coke]         Canned SodaCanned SodaCanned Soda6 Pack Soft D...
#
#                     item_price
# choice_description
# [Diet Coke]             326.71

# %%
df.quantity.sum()
df.order_id.dtype
# Out:
# dtype('int64')

# %%
# key=lambda x:float(x[1:-1])
# df.item_price=df.item_price.apply(key)
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df['revenue']=df['quantity']*df['item_price']
df['revenue'].sum()
# Out:
# np.float64(39237.02)

# %%
df.order_id.value_counts().count()
# Out:
# np.int64(1834)

# %%
x=df.groupby('order_id').sum()
print(x['revenue'].mean())
# Out:
# 21.39423118865867

# %%
len(df[df.item_price>10.00])
# Out:
# 1130

# %%
filtered=df.drop_duplicates(['item_name','choice_description'])
filtered
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4602      1827         1                       Barbacoa Burrito
# 4607      1829         1                          Steak Burrito
# 4610      1830         1                          Steak Burrito
# 4611      1830         1                         Veggie Burrito
# 4612      1831         1                          Carnitas Bowl
#
#                                      choice_description  item_price  revenue
# 0                                                   NaN        2.39     2.39
# ...

# %%
filtered=filtered.loc[filtered['item_price']>10.0 ,['item_price']].reset_index(drop=True)
filtered
# Out:
#      item_price
# 0         16.98
# 1         10.98
# 2         11.75
# 3         11.25
# 4         10.98
# ..          ...
# 754       11.75
# 755       11.75
# 756       11.75
# 757       11.75
# 758       11.25
#
# [759 rows x 1 columns]
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
